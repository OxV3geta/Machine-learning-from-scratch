# %%
print("yo yo!")
# Out:
# yo yo!

# %% [markdown]
# ### Python Example

# %%
if True:
    print("DBZ")
    if False:
       print("bruh") 
    print("khamehamehaa")   
print("final flash")
# Out:
# DBZ
# khamehamehaa
# final flash
