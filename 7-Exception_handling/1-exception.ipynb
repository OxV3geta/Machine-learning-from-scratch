# %% [markdown]
# ### Exception handle
# exception handling in python allows you to handle errors gracefully and take corrective actions without stopping execution of the program.

# %%
### Exception try,except block
try:
    a = b
except: 
    print("the variable has not been assigned")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 ### Exception try,except block
#       2 # try:
# ----> 3 a = b
#       4 # except:
#       5 #     print("the variable has not been assigned")
#
# NameError: name 'b' is not defined

# %%
try:
    a = b
except NameError as er: 
    print(er)
# Out:
# name 'b' is not defined

# %%
## 'Exception' keyword can handle any kind error exception.
try:
    result = 1/2
    a=b
except ZeroDivisionError as er:
    print(er)
    print("please enter the denominator greater than 0")
except Exception as er1:
    print(er1)
    print("main exception got caught here")
# Out:
# name 'b' is not defined
# main exception got caught here

# %%
try:
    num = int(input("Enter a number"))
    result = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("Enter denominator greater than 0")
except Exception as er:
    print(er)
# Out:
# This is not a valid number

# %%
## try,except,else block

try:
    num = int(input("Enter a number"))
    result = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("you can't divide by zero!")
except Exception as er:
    print(er)
else:
    print(f"the result is {result}")
# Out:
# This is not a valid number

# %%
### try,except,else and finally

try:
    num = int(input("Enter a number"))
    result = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("you can't divide by zero!")
except Exception as er:
    print(er)
else:
    print(f"the result is {result}")
finally:
    print("Execution complete")
# Out:
# This is not a valid number
# Execution complete

# %%
## file handling and exception handling
try:
    file = open('example1.txt','r')
    content = file.read()
    a=b
    print(content)
    
except FileNotFoundError:
    print("The file does not exists")
except Exception as er:
    print(er)
finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print('file close')
# Out:
# name 'b' is not defined
# file close
