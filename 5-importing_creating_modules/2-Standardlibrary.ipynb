# %% [markdown]
# ### Standard Library Overview

# %%
import array

arr = array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math 
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
##random
import random
print(random.randint(1,10))
print(random.choice(['apple','bannana','cherry']))
# Out:
# 5
# cherry

# %%
import os
print(os.getcwd())
# Out:
# /media/oxv3geta/Work/python for Ml/5-importing_creating_modules

# %%
os.mkdir("test_dir")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 os.mkdir("test_dir")
#
# FileExistsError: [Errno 17] File exists: 'test_dir'

# %%
## high level operation on files and high level files
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data serialization
import json

data = {'name':'Vegeta','age':46}
print(type(data))

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# <class 'dict'>
# <class 'str'>
# {'name': 'Vegeta', 'age': 46}
# <class 'dict'>

# %%
## CSV

import csv

with open("example.csv",mode = 'w',newline = '') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age','form'])
    writer.writerow(['Vegeta','47','Ultra Ego'])
    writer.writerow(['Goku','42','Ultra Instinct'])
    
    with open("example.csv",mode = 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            print(row)

# %%
## datetime

from datetime import datetime,timedelta

today = datetime.now()
yesterday = today - timedelta(days=2)

# print(bruh)
print(today)
print(yesterday)
# Out:
# 2026-05-20 20:51:45.731188
# 2026-05-18 20:51:45.731188

# %%
## time

import time
print(time.time())
time.sleep(3)
print(time.time())
# Out:
# 1779288717.8806205
# 1779288720.8808844

# %%
## reguler expression

import re

pattern = r'\d+'
text = "There are 32 mangos"
match = re.search(pattern,text)
print(match.group())
# Out:
# 32
