# %%
class Shape:
    def area(self):
        return f"the area of the shape"

class Rectangle(Shape):
    def __init__(self,length,width):
        self.length = length
        self.width = width 
    def area(self):
        return self.length*self.width

class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius
    def area(self):
        return 3.1416*self.radius**2
def print_area(shape):
    return f"the area is {shape.area()}"

x = Rectangle(7,5)
y = Circle(3)

print(print_area(x))
print(print_area(y))
# Out:
# the area is 35
# the area is 28.2744

# %%
from abc import ABC,abstractmethod

class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        return "Car engine started!"

class Motorcycle(Vehicle):
    def start_engine(self):
        return "Motorcycle engine started!"

def start_vehicle(vehicle):
    print(vehicle.start_engine())
    
car = Car()
motor = Motorcycle()

start_vehicle(car)
# Out:
# Car engine started!

# %%
class Person:
    def __init__(self,name,age,gender):
        self.__name = name
        self.__age = age
        self.gender = gender
    
    def get_name(self):
        return self.__name

p = Person("niga",69,'M')
print(p.get_name())
# Out:
# niga

# %%
dir(p)

# %%
class Person:
    def __init__(self,name,form,age):
        self._name = name
        self._form = form
        self._age = age

class Saiyan(Person):
    def __init__(self,name,form,age):
        super().__init__(name,form,age)

saiyan = Saiyan("Vegeta","Ultra ego",47)
print(saiyan._name)
# Out:
# Vegeta

# %%
class Saiyan:
    def __init__(self,name,form,age):
        self.__name = name
        self.__form = form
        self.__age = age
        
    def get_name(self):
        return self.__name
    
    def set_name(self,new_name):
        self.__name = new_name
    
    def get_form(self):
        return self.__form
    
    def set_form(self,new_form):
        self.__form = new_form
    
    def get_age(self):
        return self.__age
    
    def set_age(self):
        return self.__age
    
s = Saiyan("Vegeta","Ultra Ego",47)
# print(s.get_name())
# print(s.get_form())

s.set_name("Goku")
print(s.get_name())
# s.set_form("Ultra instict")
# print(s.get_form())
# Out:
# Goku

# %%
from abc import ABC,abstractmethod

class vehicle:
    def drive(self):
        print("The vehicle is used for transport.")
    
    @abstractmethod
    def start_engine(self):
        pass
    
class Car(vehicle):
    def start_engine(self):
        print("car engine started")

def operate_vehicle(vehicle):
    vehicle.start_engine()
    vehicle.drive()
    
car = Car()
operate_vehicle(car)
# Out:
# car engine started
# The vehicle is used for transport.

# %%
class Vehicle:
    def drive(self):
        print("The vehicles is used for hospital.")
    
    @abstractmethod
    def start_engine(self):
        pass
    
class Car(Vehicle):
    def start_engine(self):
        print("the car engine's started.")

def operate_vehicle(vehicle):
    vehicle.start_engine()
    vehicle.drive()

car = Car()
operate_vehicle(car)
# Out:
# the car engine's started.
# The vehicles is used for hospital.

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    
    def __str__(self):
        return f"name:{self.name},age:{self.age}"
        
    def __repr__(self):
        return f"person(name is {self.name} and age:{self.age})"
    
person = Person("bruh",69)
print(person)
print(repr(person))
# Out:
# name:bruh,age:69
# person(name is bruh and age:69)
