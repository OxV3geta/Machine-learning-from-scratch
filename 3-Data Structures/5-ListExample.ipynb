# %%
to_do_list =["buy pen","clean desk","pay bills"]

to_do_list.append("meeting")
to_do_list.append("go for run")

to_do_list.remove("clean desk")

if "pay bills" in to_do_list:
    print("pay the bills in 2 days")

print("remaining list:")
for task in to_do_list:
    print(f"-{task}")
# Out:
# pay the bills in 2 days
# remaining list:
# -buy pen
# -pay bills
# -meeting
# -go for run
