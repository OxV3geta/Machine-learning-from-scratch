# %% [markdown]
# ### Example of Function

# %%
def conv_temp(temp,unit):
    if unit == 'c':
        fahrenheit = (temp * 9/5) + 32
        return fahrenheit
    elif unit == 'f':
        celsius = (temp - 32) * 5/9
        return celsius
    else:
        return "Invalid"
    
    
temperature = conv_temp(float(input("Enter the temp")),unit = input("Enter the unit you"))
print(temperature)
# Out:
# 4.444444444444445

# %%
def is_strong_password(password):
    if len(password)<8:
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char in '!@#$%^&*()_+' for char in password):
        return False
    return True

print(is_strong_password("qwqe123"))
print(is_strong_password("12QWer#$"))
# Out:
# True
# True

# %%
def calculate_cost(cart):
    total_cost = 0
    for item in cart:
        total_cost+= item["price"]*item["quantity"]
    return total_cost

cart = [
    {"name":"cpu","price":250,"quantity":5},
    {"name":"gpu","price":500,"quantity":10},
    {"name":"monitor","price":300,"quantity":5}
]

print(calculate_cost(cart))
# Out:
# 7750

# %%
def palindrome(s):
    s = s.replace(" ","").lower()
    if s == s[::-1]:
        print("it's palindrome")
    else:
        print("it's not a palindrome")
    return s[::-1]
check = palindrome("Race car")
print(check)
# Out:
# it's palindrome
# racecar

# %%
def factorial(n):
    if n!=0:
        return n * factorial(n-1)
    else:
        return 1

print(factorial(5))
# Out:
# 20

# %%
def count_word_frequency(file_path):
    word_count = {}
    with open(file_path,'r') as file:
        for line in file:
            words = line.split()
            for word  in words:
                word = word.lower().strip("<>?:,./;")
                word_count[word] = word_count.get(word,0)+1

    return word_count

file_path = "sample.txt"
count =  count_word_frequency(file_path)

print(count)
# Out:
# {'hello': 1, 'world': 1, 'how': 1, 'are': 1, 'you': 1, "i'm": 1, 'legendary': 1, 'super': 1, 'saiyan': 1, 'son': 1, 'goku': 2, 'the': 1, 'monkey': 1}
