# %% [markdown]
# ### File Operation - Read and Write files

# %%
## Read a whole file

with open('example.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# Hello,Hi....
# I'm legendary super saiyan,
# son gokuuuuuuu.
# But I'm vegeta.

# %%
## Read a file line by line

with open('example.txt','r') as file:
    for line in file:
        print(line.strip()) ##.strip() removes the newline character
# Out:
# Hello,Hi....
# I'm legendary super saiyan,
# son gokuuuuuuu.
# But I'm vegeta.

# %%
## wrinting a file(overwriting)

with open("example.txt",'w') as file:
    file.write('Hello World!\n')
    file.write('this is a new line.')

# %%
## write a file(without overwriting)
with open("example.txt",'a') as file:
    file.write("Append operation taking place!\n")

# %%
## writing a list of lines to a file
lines = ['first line \n','second line \n','third line\n']
with open("example.txt",'a') as file:
    file.writelines(lines)

# %%
## binary Files

#writing to a binary file

data = b'\x00\x01\x02\x03\x04'
with open('example.bin','wb') as file:
    file.write(data)

# %%
# read
with open('example.bin','rb') as file:
    content = file.read()
    print(content)
# Out:
# [b'\x00\x01\x02\x03\x04']

# %%
### Read the content from source text file and write to a destination text file
# copying a text file

with open('example.txt','r') as file:
    content = file.read()


with open('destination.txt','w') as destination_file:
    destination_file.write(content)

# %%
# with open('example.txt','r') as file:
#     lines = file.readlines()
#     print(lines)
#     line_count = len(lines)
#     word_count = sum(len(line.split()) for line in lines)
#     char_count = sum(len(line) for line in lines)
#     print(f'lines:{line_count} ,words:{word_count} ,character:{char_count}')
# Out:
# ['Hello World!\n', 'this is a new line.first line \n', 'second line \n', 'third line\n']
# lines:4 ,words:12 ,character:68

# %%
### writing and reading file
''' w+ using for both reading and writing.if file doesn't exist,it will be created.if the file exists,
its content is truncated.
'''
with open('example.txt','w+') as file:
    file.write("Hello Earth\n")
    file.write("this is a new line\n")

### move the  file cursor to the beginning
    file.seek(0)

## read the file content of the file
    content = file.read()
    print(content)
# Out:
# Hello Earth
# this is a new line

# %%
with open('destination.txt','r') as file:
    lines = file.readlines()
    # print(lines)
    line_count = len(lines)
    word_count = sum((len(line.split()) for line in lines))
    char_count = sum(len(line) for line in lines)
    print(f'lines:{line_count} ,words:{word_count} ,character:{char_count}')
# Out:
# lines:4 ,words:12 ,character:68
