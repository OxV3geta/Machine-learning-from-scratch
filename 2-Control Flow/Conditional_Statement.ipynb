# %% [markdown]
# ### if & elif statement

# %%
## if  statement

age = 18

if age >= 18:
    print("you allow")
# Out:
# you allow

# %%
## elif
age = 33

if age <= 13:
    print("you a child")
elif age <= 18:
    print("you are teenager")
else:
    print("you are adult")
# Out:
# you are adult

# %%
## Nested conditional statement
x = int(input("Enter a number: "))

if x >= 0:
    print("Number is positive.")
    if x%2 == 0:
        print("Number is even")
    else:
        print("Number is odd")
else:
    print("Number is negative or zero")
# Out:
# Number is positive.
# Number is even

# %%
## leap year example

year = int(input("Enter a year:"))

if year%4 == 0:
    if year%100 == 0:
        if year%400 == 0:
            print("This is a leap year.")
        else:
            print("This is not a leap year!")
    else:
        print("this is leap year")
        
else:
    print("this is not leap year")
# Out:
# this is leap year

# %%
## Assignment 1

x = float(input("Enter number 1 :"))
y = float(input("Enter number 2 :"))
operation = input("Enter (+ , - , * ,/) :")

if operation == '+':
    result = x + y
elif operation == '-':
    result = x - y
elif operation == '*':
    result = x * y
elif operation == '/':
    if y != 0:
        result = x/y
    else:
        result = "Error! Division by zero"
else:
    print("invalid inputs")

print(f"the result is {result}")

# %%
## Assignment 2 
age = int(input("Enter your age: "))
occupation = input("Enter your occupation: ")

if age <= 10:
    print("for child it's free")
elif age <= 18:
    if occupation == "student":
        print("the price for student is 100.")
    else:
        print("the price for under 18 is 50.")
elif age>=18:
    if occupation == "student":
        print("the price for student is 100.")
    else:
        print("the price for adults is 300.")

else:
    print("the price for adults is 300.")
# Out:
# the price for under 18 is 100.
